# %%
import pandas as pd

# %%
df_books = pd.read_csv('./data/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv', sep=',', header=0)
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %% [markdown]
# ### Drop columns

# %%
# Usamos el comando eliminamos la columna: .drop('[Nombre Columna]', axis=1)
# esto en realidad es mostrar el dataframe sin la columna indicada
# axis=1: columnas
# axis=0: filas

df_books.drop('Genre', axis=1).head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
# Si queremos eliminarla del dataframe, tendremos que añadir el parámetro
# inplace=True

df_books.drop('Genre', axis=1, inplace=True)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price
# 0                    JJ Smith          4.7    17350      8
# 1                Stephen King          4.6     2052     22
# 2          Jordan B. Peterson          4.7    18979     15
# 3               George Orwell          4.7    21424      6
# ...

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22

# %%
# Otra manera es reasignar el valor del dataframe con la columna eliminada
df_books = df_books.drop('Year', axis=1)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price
# 0                    JJ Smith          4.7    17350      8
# 1                Stephen King          4.6     2052     22
# 2          Jordan B. Peterson          4.7    18979     15
# 3               George Orwell          4.7    21424      6
# ...

# %%
# Otra manera es eliminar la columna usando la función built-in de Python

del df_books['Price']

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews
# 0                    JJ Smith          4.7    17350
# 1                Stephen King          4.6     2052
# 2          Jordan B. Peterson          4.7    18979
# 3               George Orwell          4.7    21424
# ...

# %% [markdown]
# ## Drop rows

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
# En ves de indicar el nombre de la columna, tendremos que indicar el índice de fila
# Y en el caso del axis se coloca 0 para indicar la fila (0 fila, 1 columna)

df_books.drop(0, axis=0).head(2)
# Out:
#                                       Name              Author  User Rating  \
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction

# %%
# Podemos eliminar una lista
# Como no hems usado inplace los cambios no se han guardado

df_books.drop([0,1,2], axis=0).head(2)
# Out:
#                                                 Name  \
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# También nos permite usar range() para elminar un rango de filas
# incluso podemos usar el step para eliminar cada cierto número de filas

df_books.drop(range(0,10,2), axis=0).head(100)
# Out:
#                                                   Name               Author  \
# 1                                    11/22/63: A Novel         Stephen King
# 3                               1984 (Signet Classics)        George Orwell
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 7                       A Gentleman in Moscow: A Novel          Amor Towles
# 9                            A Man Called Ove: A Novel      Fredrik Backman
# ..                                                 ...                  ...
# 100                                     Fahrenheit 451         Ray Bradbury
# 101                                     Fahrenheit 451         Ray Bradbury
# 102  Fantastic Beasts and Where to Find Them: The O...         J.K. Rowling
# 103                     Fear: Trump in the White House         Bob Woodward
# 104                                Fifty Shades Darker            E L James
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %% [markdown]
# ## Add columns

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
# Para agregar una nueva columna, usamos la notación de llamar al dataframe y nombrar un nueva columna
# luego le damos un valor, para ello nos apoyamos con Numpy (np.nan: crea un valor NaN o no numérico (Not a Number))

import numpy as np

df_books['Nueva Columna'] = np.nan

# %%
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Ahora podemos crear un arange con Numpy llamado data

data = np.arange(0,df_books.shape[0])

# %%
# Y su valor agregarlo al dataframe como una nueva columna

df_books['Rango'] = data

# %%
# La regla es que la nueva columna debe tener la misma cantidad de filas que las ya existentes
# Para saber la cantidad nos podemos apoyar con [nombre dataframe].shape[0]
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ## Add rows

# %%
# En Pandas hay una función similar al append de las listas que se llama .append()
# Se utilizar para agregar filas o registros

# Ejemplo:
# Agregar el mismo df, esto nos creo un duplicado agregado al df
df_books.append(df_books)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Para este caso incluso nos agregó los encabezados

df_books.iloc[550:551,:]
# Out:
# Empty DataFrame
# Columns: [Name, Author, User Rating, Reviews, Price, Year, Genre, Nueva Columna, Rango]
# Index: []
